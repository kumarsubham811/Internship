# %% [markdown]
# # PROJECT 2 - MEDICAL COST PERSONAL INSURANCE PROJECT
# # NAME - SUBHAM
# # BATCH - DS2401

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
#
#
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
#
# bmi
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: count, Length: 548, dtype: int64
#
#
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64
#
#
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
#
#
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64
#
#
# charges
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: count, Length: 1337, dtype: int64

# %%
for i in df.columns:
    print(i,df[i].unique())
    print('\n')
# Out:
# age [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
#
# sex ['female' 'male']
#
#
# bmi [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
#  38.28  19.95  19.3   31.6   25.46  30.115 29.92  27.5   28.4   30.875
#  27.94  35.09  29.7   35.72  32.205 28.595 49.06  27.17  23.37  37.1
#  23.75  28.975 31.35  33.915 28.785 28.3   37.4   17.765 34.7   26.505
#  22.04  35.9   25.555 28.05  25.175 31.9   36.    32.49  25.3   29.735
#  38.83  30.495 37.73  37.43  24.13  37.145 39.52  24.42  27.83  36.85
#  39.6   29.8   29.64  28.215 37.    33.155 18.905 41.47  30.3   15.96
#  33.345 37.7   27.835 29.2   26.41  30.69  41.895 30.9   32.2   32.11
#  31.57  26.2   30.59  32.8   18.05  39.33  32.23  24.035 36.08  22.3
#  26.4   31.8   26.73  23.1   23.21  33.7   33.25  24.64  33.88  38.06
#  41.91  31.635 36.195 17.8   24.51  22.22  38.39  29.07  22.135 26.8
#  30.02  35.86  20.9   17.29  34.21  25.365 40.15  24.415 25.2   26.84
#  24.32  42.35  19.8   32.395 30.2   29.37  34.2   27.455 27.55  20.615
#  24.3   31.79  21.56  28.12  40.565 27.645 31.2   26.62  48.07  36.765
#  33.4   45.54  28.82  22.99  27.7   25.41  34.39  22.61  37.51  38.
#  33.33  34.865 33.06  35.97  31.4   25.27  40.945 34.105 36.48  33.8
#  36.7   36.385 34.5   32.3   27.6   29.26  35.75  23.18  25.6   35.245
#  43.89  20.79  30.5   21.7   21.89  24.985 32.015 30.4   21.09  22.23
#  32.9   24.89  31.46  17.955 30.685 43.34  39.05  30.21  31.445 19.855
#  31.02  38.17  20.6   47.52  20.4   38.38  24.31  23.6   21.12  30.03
#  17.48  20.235 17.195 23.9   35.15  35.64  22.6   39.16  27.265 29.165
#  16.815 33.1   26.9   33.11  31.73  46.75  29.45  32.68  33.5   43.01
#  36.52  26.695 25.65  29.6   38.6   23.4   46.53  30.14  30.    38.095
#  28.38  28.7   33.82  24.09  32.67  25.1   32.56  41.325 39.5   34.3
#  31.065 21.47  25.08  43.4   25.7   27.93  39.2   26.03  30.25  28.93
#  35.7   35.31  31.    44.22  26.07  25.8   39.425 40.48  38.9   47.41
#  35.435 46.7   46.2   21.4   23.8   44.77  32.12  29.1   37.29  43.12
#  36.86  34.295 23.465 45.43  23.65  20.7   28.27  35.91  29.    19.57
#  31.13  21.85  40.26  33.725 29.48  32.6   37.525 23.655 37.8   19.
#  21.3   33.535 42.46  38.95  36.1   29.3   39.7   38.19  42.4   34.96
#  42.68  31.54  29.81  21.375 40.81  17.4   20.3   18.5   26.125 41.69
#  24.1   36.2   40.185 39.27  34.87  44.745 29.545 23.54  40.47  40.66
#  36.6   35.4   27.075 28.405 21.755 40.28  30.1   32.1   23.7   35.5
#  29.15  27.    37.905 22.77  22.8   34.58  27.1   19.475 26.7   34.32
#  24.4   41.14  22.515 41.8   26.18  42.24  26.51  35.815 41.42  36.575
#  42.94  21.01  24.225 17.67  31.5   31.1   32.78  32.45  50.38  47.6
#  25.4   29.9   43.7   24.86  28.8   29.5   29.04  38.94  44.    20.045
#  40.92  35.1   29.355 32.585 32.34  39.8   24.605 33.99  28.2   25.
#  33.2   23.2   20.1   32.5   37.18  46.09  39.93  35.8   31.255 18.335
#  42.9   26.79  39.615 25.9   25.745 28.16  23.56  40.5   35.42  39.995
#  34.675 20.52  23.275 36.29  32.7   19.19  20.13  23.32  45.32  34.6
#  18.715 21.565 23.    37.07  52.58  42.655 21.66  32.    18.3   47.74
#  22.1   19.095 31.24  29.925 20.35  25.85  42.75  18.6   23.87  45.9
#  21.5   30.305 44.88  41.1   40.37  28.49  33.55  40.375 27.28  17.86
#  33.3   39.14  21.945 24.97  23.94  34.485 21.8   23.3   36.96  21.28
#  29.4   27.3   37.9   37.715 23.76  25.52  27.61  27.06  39.4   34.9
#  22.    30.36  27.8   53.13  39.71  32.87  44.7   30.97 ]
#
#
# children [0 1 3 2 5 4]
#
#
# smoker ['yes' 'no']
#
#
# region ['southwest' 'southeast' 'northwest' 'northeast']
#
#
# charges [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %%
for i in df.columns:
    print(i,df[i].nunique())
    print('\n')
# Out:
# age 47
#
#
# sex 2
#
#
# bmi 548
#
#
# children 6
#
#
# smoker 2
#
#
# region 4
#
#
# charges 1337

# %% [markdown]
# # Description Of Dataset

# %%
#statistical summary of numerical column
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.heatmap(df.describe(),annot=True ,fmt='0.2f' ,linewidth=0.2,linecolor='black',cmap='crest' )
# Out:
# <Axes: >

# %% [markdown]
# # checking skewness

# %%
plt.figure(figsize=(20,25))
p=1
for i in df.columns:
    if p<=12:
        ax=plt.subplot(4,4,p)
        sns.distplot(df[i])
    p+=1

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
df['charges']=np.cbrt(df['charges'])
df['smoker']=np.cbrt(df['smoker'])
df['children']=np.cbrt(df['children'])

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children   -0.097116
# smoker      1.464766
# region     -0.038101
# charges     0.515183
# dtype: float64

# %%
df['smoker']=np.cbrt(df['smoker'])

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children   -0.097116
# smoker      1.464766
# region     -0.038101
# charges     0.515183
# dtype: float64

# %%
plt.figure(figsize=(20,25))
p=1
for i in df.columns:
    if p<=12:
        ax=plt.subplot(4,4,p)
        sns.distplot(df[i])
    p+=1

# %% [markdown]
# # checking for outliers

# %%
plt.figure(figsize=(20,25))
p=1
for i in df.columns:
    if p<=12:
        ax=plt.subplot(4,4,p)
        sns.boxplot(df[i])
        plt.xlabel(i)
    p+=1

# %%
from scipy.stats import zscore
a=df[['age','sex','bmi','children','smoker','region','charges']]
z=np.abs(zscore(a))
z
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  1.117604  1.970587  1.343905  0.592496
# 1     1.509965  0.989591  0.509621  0.502009  0.507463  0.438495  1.475201
# 2     0.797954  0.989591  0.383307  1.218282  0.507463  0.438495  0.801132
# 3     0.441948  0.989591  1.305531  1.117604  0.507463  0.466915  0.949586
# 4     0.513149  0.989591  0.292556  1.117604  0.507463  0.466915  0.914914
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.218282  0.507463  0.466915  0.034353
# 1334  1.509965  1.010519  0.206139  1.117604  0.507463  1.372326  1.320300
# 1335  1.509965  1.010519  1.014878  1.117604  0.507463  0.438495  1.509411
# 1336  1.296362  1.010519  0.797813  1.117604  0.507463  1.343905  1.381121
# 1337  1.551686  1.010519  0.261388  1.117604  1.970587  0.466915  1.367233
#
# [1338 rows x 7 columns]

# %%
df1=z[(z<3).all(axis=1)]
df1
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  1.117604  1.970587  1.343905  0.592496
# 1     1.509965  0.989591  0.509621  0.502009  0.507463  0.438495  1.475201
# 2     0.797954  0.989591  0.383307  1.218282  0.507463  0.438495  0.801132
# 3     0.441948  0.989591  1.305531  1.117604  0.507463  0.466915  0.949586
# 4     0.513149  0.989591  0.292556  1.117604  0.507463  0.466915  0.914914
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.218282  0.507463  0.466915  0.034353
# 1334  1.509965  1.010519  0.206139  1.117604  0.507463  1.372326  1.320300
# 1335  1.509965  1.010519  1.014878  1.117604  0.507463  0.438495  1.509411
# 1336  1.296362  1.010519  0.797813  1.117604  0.507463  1.343905  1.381121
# 1337  1.551686  1.010519  0.261388  1.117604  1.970587  0.466915  1.367233
#
# [1334 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df1.shape
# Out:
# (1334, 7)

# %%
# 4 rows removed

# %% [markdown]
# # check for correlation and multicollinearity

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.048919 -0.025019  0.002127  0.451354
# sex      -0.020856  1.000000  0.046371  0.016183  0.076185  0.004588  0.027560
# bmi       0.109272  0.046371  1.000000  0.016515  0.003750  0.157566  0.156375
# children  0.048919  0.016183  0.016515  1.000000  0.011829  0.014133  0.128511
# smoker   -0.025019  0.076185  0.003750  0.011829  1.000000 -0.002181  0.732564
# region    0.002127  0.004588  0.157566  0.014133 -0.002181  1.000000 -0.029807
# charges   0.451354  0.027560  0.156375  0.128511  0.732564 -0.029807  1.000000

# %%
df1.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.001981  0.006289  0.171589 -0.018997 -0.001748  0.184246
# sex       0.001981  1.000000  0.014857  0.000323 -0.076096  0.003070 -0.101532
# bmi       0.006289  0.014857  1.000000 -0.002783  0.028430 -0.024166  0.016533
# children  0.171589  0.000323 -0.002783  1.000000  0.006762  0.024116  0.019177
# smoker   -0.018997 -0.076096  0.028430  0.006762  1.000000 -0.029931  0.543676
# region   -0.001748  0.003070 -0.024166  0.024116 -0.029931  1.000000 -0.076532
# charges   0.184246 -0.101532  0.016533  0.019177  0.543676 -0.076532  1.000000

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df1.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
df2=pd.DataFrame(s.fit_transform(df1),columns=df1.columns)
df2
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.160563  1.007525 -0.591365  0.558127  1.971407  0.995543 -0.339668
# 1     1.306063 -0.992532 -0.494130 -1.612913 -0.507252 -1.002649  1.128225
# 2    -0.148934 -0.992532 -0.712281  0.913190 -0.507252 -1.002649  0.007283
# 3    -0.876432 -0.992532  0.880447  0.558127 -0.507252 -0.939926  0.254154
# 4    -0.730932 -0.992532 -0.869012  0.558127 -0.507252 -0.939926  0.196497
# ...        ...       ...       ...       ...       ...       ...       ...
# 1329 -0.209178 -0.992532 -1.287407  0.913190 -0.507252 -0.939926 -1.267831
# 1330  1.306063  1.007525 -1.018260  0.558127 -0.507252  1.058266  0.870634
# 1331  1.306063  1.007525  0.378475  0.558127 -0.507252 -1.002649  1.185116
# 1332  0.869564  1.007525  0.003593  0.558127 -0.507252  0.995543  0.971776
# 1333  1.391318  1.007525 -0.922842  0.558127  1.971407 -0.939926  0.948681
#
# [1334 rows x 7 columns]

# %%
# vif factor is checked for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(df2.values,i) for i in range(len(df2.columns))]
vif['features']=df2.columns
vif
# Out:
#    VIF values  features
# 0    1.090024       age
# 1    1.011682       sex
# 2    1.001707       bmi
# 3    1.031540  children
# 4    1.452445    smoker
# 5    1.007431    region
# 6    1.517362   charges

# %%
# multicollinearity not present as vif values of all columns are close to 1 so they are not much related with each other

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])

# %%
df['smoker']=le.fit_transform(df['smoker'])

# %%
df['region']=le.fit_transform(df['region'])

# %%
x=df.iloc[:,:-1]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900   0.00000     1.0       3
# 1      18    1  33.770   1.00000     0.0       2
# 2      28    1  33.000   1.44225     0.0       2
# 3      33    1  22.705   0.00000     0.0       1
# 4      32    1  28.880   0.00000     0.0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970   1.44225     0.0       1
# 1334   18    0  31.920   0.00000     0.0       0
# 1335   18    0  36.850   0.00000     0.0       2
# 1336   21    0  25.800   0.00000     0.0       3
# 1337   61    0  29.070   0.00000     1.0       1
#
# [1338 rows x 6 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       25.654666
# 1       11.994331
# 2       16.447599
# 3       28.013799
# 4       15.695891
#           ...
# 1333    21.967271
# 1334    13.017690
# 1335    11.768318
# 1336    12.615872
# 1337    30.773007
# Name: charges, Length: 1338, dtype: float64

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr= LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('max r2 is',maxaccu,'at random state',maxrs)
# Out:
# max r2 is 0.8273389787575156 at random state 112

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('max r2 is',maxaccu,'at random state',maxrs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\3959812250.py in ?()
#       2 maxrs=0
#       3 for i in range(1,200):
#       4     x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
#       5
# ----> 6     rfr.fit(x_train,y_train)
#       7     pred=rfr.predict(x_test)
#       8     acc=r2_score(y_test,pred)
#       9     if acc>maxaccu:
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr= LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('max r2 is',maxaccu,'at random state',maxrs)
# Out:
# max r2 is 0.8041576323426198 at random state 112

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)

# %%
from sklearn.linear_model import LinearRegression as lr
from sklearn.ensemble import RandomForestRegressor as rfr
from sklearn.tree import DecisionTreeRegressor as dtr
from sklearn.neighbors import KNeighborsRegressor as knn
from sklearn.linear_model import Lasso as l , Ridge as r

# %%
x_train
# Out:
#       age  sex    bmi  children  smoker  region
# 1146   60    1  32.80         0       1       3
# 178    46    0  28.90         2       0       3
# 590    58    0  29.00         0       0       3
# 989    24    0  20.52         0       1       0
# 826    56    1  31.79         2       1       2
# ...   ...  ...    ...       ...     ...     ...
# 1221   40    1  24.97         2       0       2
# 1012   61    0  33.33         4       0       2
# 321    26    0  29.64         4       0       0
# 232    19    0  17.80         0       0       3
# 939    53    1  29.48         0       0       2
#
# [936 rows x 6 columns]

# %%
y_train
# Out:
# 1146    52590.82939
# 178      8823.27900
# 590     11842.44200
# 989     14571.89080
# 826     43813.86610
#            ...
# 1221     6593.50830
# 1012    36580.28216
# 321     24671.66334
# 232      1727.78500
# 939      9487.64420
# Name: charges, Length: 936, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
pred_train_lr=lr.predict(x_train)
print(lr)
print('r2 score',r2_score(y_test,predlr))
print('r2 score on training data',r2_score(y_train,pred_train_lr))
print('mean absloute error',mean_absolute_error(y_test,predlr))
print('mean squared error',mean_squared_error(y_test,predlr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# LinearRegression()
# r2 score 0.8041576323426198
# r2 score on training data 0.7253763959645672
# mean absloute error 3916.5692655615812
# mean squared error 29880673.555641137
# root mean squared error 5466.321757419804

# %%
from sklearn.ensemble import RandomForestRegressor as rfr
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
pred_train_rfr=rfr.predict(x_train)
print(rfr)
print('r2 score',r2_score(y_test,predrfr))
print('r2 score on training data',r2_score(y_train,pred_train_rfr))
print('mean absloute error',mean_absolute_error(y_test,predrfr))
print('mean squared error',mean_squared_error(y_test,predrfr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predrfr)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\2880753703.py in ?()
#       1 from sklearn.ensemble import RandomForestRegressor as rfr
#       2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
# ----> 3 rfr.fit(x_train)
#       4 predrfr=rfr.predict(x_test)
#       5 pred_train_rfr=rfr.predict(x_train)
#       6 print(rfr)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
r=[0,1,2,3,4]
t=[9,8,7,6,5]
rfr.fit(r,t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 3
#       1 r=[0,1,2,3,4]
#       2 t=[9,8,7,6,5]
# ----> 3 rfr.fit(r,t)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1144, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1139 partial_fit_and_fitted = (
#    1140     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141 )
#    1143 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
#    1151     return fit_method(estimator, *args, **kwargs)
#
# AttributeError: 'list' object has no attribute '_validate_params'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train_knn=knn.predict(x_train)
print(knn)
print('r2 score',r2_score(y_test,predknn))
print('r2 score on training data',r2_score(y_train,pred_train_knn))
print('mean absloute error',mean_absolute_error(y_test,predknn))
print('mean squared error',mean_squared_error(y_test,predknn))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\2704295368.py in ?()
#       1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
# ----> 2 knn.fit(x_train,y_train)
#       3 predknn=knn.predict(x_test)
#       4 pred_train_knn=knn.predict(x_train)
#       5 print(knn)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
pred_train_dtr=dtr.predict(x_train)
print(dtr)
print('r2 score',r2_score(y_test,preddtr))
print('r2 score on training data',r2_score(y_train,pred_train_dtr))
print('mean absloute error',mean_absolute_error(y_test,preddtr))
print('mean squared error',mean_squared_error(y_test,preddtr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\2940898577.py in ?()
#       1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
# ----> 2 dtr.fit(x_train,y_train)
#       3 preddtr=dtr.predict(x_test)
#       4 pred_train_dtr=dtr.predict(x_train)
#       5 print(dtr)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
l.fit(x_train,y_train)
predl=l.predict(x_test)
pred_train_l=l.predict(x_train)
print(l)
print('r2 score',r2_score(y_test,predl))
print('r2 score on training data',r2_score(y_train,pred_train_l))
print('mean absloute error',mean_absolute_error(y_test,predl))
print('mean squared error',mean_squared_error(y_test,predl))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predl)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\445758870.py in ?()
#       1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
# ----> 2 l.fit(x_train,y_train)
#       3 predl=l.predict(x_test)
#       4 pred_train_l=l.predict(x_train)
#       5 print(l)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
r.fit(x_train,y_train)
predr=r.predict(x_test)
pred_train_r=r.predict(x_train)
print(r)
print('r2 score',r2_score(y_test,predr))
print('r2 score on training data',r2_score(y_train,pred_train_r))
print('mean absloute error',mean_absolute_error(y_test,predr))
print('mean squared error',mean_squared_error(y_test,predr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,predr)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\4210283304.py in ?()
#       1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=112)
# ----> 2 r.fit(x_train,y_train)
#       3 predr=r.predict(x_test)
#       4 pred_train_r=r.predict(x_train)
#       5 print(r)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1140                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141             )
#    1142
#    1143             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144                 estimator._validate_params()
#    1145
#    1146             with config_context(
#    1147                 skip_parameter_validation=(
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '_validate_params'

# %%
from sklearn.model_selection import cross_val_score as cvs
score=cvs(lr,x,y,scoring='r2')
print(score)
print(score.mean())
# Out:
# [0.80610264 0.70333609 0.83436131 0.77339583 0.76333225]
# 0.7761056243879787

# %%
print('differnce b/w r2 score and cross val score',0.804157-0.7761056)
# Out:
# differnce b/w r2 score and cross val score 0.02805140000000006

# %%
from sklearn.model_selection import GridSearchCV

params = {'copy_X':[True], 
          'fit_intercept':[True], 
          'n_jobs':[None], 
          'positive':[False]}
gcv=GridSearchCV(lr,params,cv=5)
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True], 'fit_intercept': [True],
#                          'n_jobs': [None], 'positive': [False]})

# %%
gcv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
pred=gcv.predict(x_test)
r2=r2_score(y_test,pred)
print(r2*100)
# Out:
# 76.47505615222799

# %%
final_model=GridSearchCV(lr,copy_X= True, fit_intercept= True, n_jobs= None, positive= False)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
r2=r2_score(y_test,pred)
print(r2*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 final_model=GridSearchCV(lr,copy_X= True, fit_intercept= True, n_jobs= None, positive= False)
#       2 final_model.fit(x_train,y_train)
#       3 pred=final_model.predict(x_test)
#
# TypeError: GridSearchCV.__init__() got an unexpected keyword argument 'copy_X'

# %%
import pickle
filename='medical cost personal insurance'
pickle.dump(gcv,open(filename,'wb'))

# %%
load=pickle.load(open('medical cost personal insurance','rb'))
result=load(x_test,y_test)
