# %% [markdown]
# # PROJECT 7 - BANK MARKETING PROJECT
# # NAME - SUBHAM
# # BATCH - DS2401

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_train.csv')
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df.shape
# Out:
# (31647, 18)

# %%
#there are 31647 rows and 18 columns in the dataset

# %%
df.dtypes
# Out:
# ID             int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %%
# we can see datatype for each column here and every datatype for each column is right

# %%
df.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
# dataset doesn't possess any null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# we can vizualise it by using heatmap. data doesn't contain any null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
# this shows that there are 31647 rows and 18 columns. 
# all columns have no null values 
# and shows datatypes of all columns e.g:- ID -> int64 , age -> int64 etc.

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# ID
# 26110    1
# 13339    1
# 39681    1
# 15135    1
# 26037    1
#         ..
# 1247     1
# 15584    1
# 25376    1
# 38699    1
# 14156    1
# Name: count, Length: 31647, dtype: int64
#
#
# age
# 32    1457
# 31    1417
# 33    1406
# 34    1321
# 35    1314
#       ...
# 92       1
# 95       1
# 93       1
# 94       1
# 90       1
# Name: count, Length: 76, dtype: int64
#
#
# job
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: count, dtype: int64
#
#
# marital
# married     19095
# single       8922
# divorced     3630
# Name: count, dtype: int64
#
#
# education
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: count, dtype: int64
#
#
# default
# no     31062
# yes      585
# ...

# %%
# we can see unique values and their value counts this way
# like for ID there are 31647 unique values and each value's value count is 1
# for age columns there are 76 unique values and for unique value 32 it's value count is 1457
# length tells total unique values and value count is shown in front of the unique value

# %% [markdown]
# # DESCRIPTION OF DATASET

# %%
#statistical summary of numerical column
df.describe()
# Out:
#                  ID           age        balance           day      duration  \
# count  31647.000000  31647.000000   31647.000000  31647.000000  31647.000000
# mean   22563.972162     40.957247    1363.890258     15.835466    258.113534
# std    13075.936990     10.625134    3028.304293      8.337097    257.118973
# min        2.000000     18.000000   -8019.000000      1.000000      0.000000
# 25%    11218.000000     33.000000      73.000000      8.000000    104.000000
# 50%    22519.000000     39.000000     450.000000     16.000000    180.000000
# 75%    33879.500000     48.000000    1431.000000     21.000000    318.500000
# max    45211.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  31647.000000  31647.000000  31647.000000
# mean       2.765697     39.576042      0.574272
# std        3.113830     99.317592      2.422529
# min        1.000000     -1.000000      0.000000
# ...

# %%
# 1)count for every column is 31647 so there are no null values 
# 2)there is skewness present in columns( if mean is greater than median(50%) then it is right skewed. if mean is less than 
# median(50%) then it is left skewed ) 
# right skewed data is ID(highly) , age , balance(highly) , duration(highly) , campaign , pdays(highly) , previous
# left skewed data is day
# 3) if there is jumped value in between 75% and max then there are outliers present
# outliers are present in columns age , balance , duration , campaign , pdays , previous

# %%
# same statistical summary can also be seen through heatmap
fig, ax = plt.subplots(figsize=(15, 5))
sns.heatmap(df.describe(),annot=True ,fmt='0.2f' ,linewidth=0.2,linecolor='black',cmap='crest' )
# Out:
# <Axes: >

# %%
# CHECKING SKEWNESS

# %%
a=('ID','age','balance','day','duration','campaign','pdays','previous')
a
# Out:
# ('ID', 'age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous')

# %%
#for checking skewness of multiple columns at the same time
plt.figure(figsize=(20,25))
p=1
for i in a:
    if p<=8:
        ax=plt.subplot(4,4,p)
        sns.distplot(df[i])
    p+=1

# %%
# we can see from the distplots that skewness is present in some of them 
# right skewed data are age , balance(highly) , duration(highly) , campaign(highly) , pdays(highly) , previous(highly)

# %%
#we can check numerical value of skewness too
# acceptable range of skewness is +0.5 to -0.5
df1=df.loc[0:,['ID','age','balance','day','duration','campaign','pdays','previous']]
df1
# Out:
#           ID  age  balance  day  duration  campaign  pdays  previous
# 0      26110   56     1933   19        44         2     -1         0
# 1      40576   31        3   20        91         2     -1         0
# 2      15320   27      891   18       240         1     -1         0
# 3      43962   57     3287   22       867         1     84         3
# 4      29842   31      119    4       380         1     -1         0
# ...      ...  ...      ...  ...       ...       ...    ...       ...
# 31642  36483   29        0   12       116         2     -1         0
# 31643  40178   53      380    5       438         2     -1         0
# 31644  19710   32      312    7        37         3     -1         0
# 31645  38556   57      225   15        22         7    337        12
# 31646  14156   55      204   11      1973         2     -1         0
#
# [31647 rows x 8 columns]

# %%
df1.skew()
# Out:
# ID           0.005851
# age          0.681607
# balance      7.995696
# day          0.087185
# duration     3.199766
# campaign     4.873935
# pdays        2.642374
# previous    49.302348
# dtype: float64

# %%
# +ve sign means right skewed and -ve sign means left skewed. we can see most columns are right skewed here and acceptable range 
# is +0.5 to -0.5

# %%
#removing skewness using cuberoot method
df1['age']=np.cbrt(df1['age'])
df1['balance']=np.cbrt(df1['balance'])
df1['duration']=np.cbrt(df1['duration'])
df1['campaign']=np.cbrt(df1['campaign'])
df1['pdays']=np.cbrt(df1['pdays'])
df1['previous']=np.cbrt(df1['previous'])

# %%
df1.skew()
# Out:
# ID          0.005851
# age         0.286363
# balance    -0.086014
# day         0.087185
# duration    0.647275
# campaign    1.667938
# pdays       1.779036
# previous    2.079738
# dtype: float64

# %%
# we can see that skewness is reduced
# there is some skewness remained in campaign , pdays and previous column 
# we can try other methods to rmove skewness as well like log method , boxcox method but cuberoot method have removed skewness 
# the most

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2=pd.Datarame()
for i in df.columns:
    if df[i].dtypes=='object':
        df2[i]=le.fit_transform(df[i].values.reshape(-1,1))
df2
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        0        1          3        0        0     0        1      9
# 1       11        1          1        0        0     0        0      5
# 2        7        1          1        0        1     0        0      5
# 3        4        0          2        0        0     0        0      6
# 4        9        1          1        0        1     0        0      3
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 31642    4        2          2        0        1     0        0      8
# 31643    4        0          2        0        0     1        0      6
# 31644    4        2          2        0        0     0        0      1
# 31645    9        1          1        0        1     0        1      8
# 31646    4        0          1        0        1     0        0      5
#
#        poutcome  subscribed
# 0             3           0
# 1             3           0
# ...

# %%
df2.describe()
# Out:
#                 job       marital     education       default       housing  \
# count  31647.000000  31647.000000  31647.000000  31647.000000  31647.000000
# mean       4.332923      1.167220      1.225013      0.018485      0.555629
# std        3.271868      0.607186      0.749195      0.134700      0.496904
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000      0.000000      0.000000
# 50%        4.000000      1.000000      1.000000      0.000000      1.000000
# 75%        7.000000      2.000000      2.000000      0.000000      1.000000
# max       11.000000      2.000000      3.000000      1.000000      1.000000
#
#                loan       contact         month      poutcome    subscribed
# count  31647.000000  31647.000000  31647.000000  31647.000000  31647.000000
# mean       0.162132      0.644642      5.533131      2.566152      0.117389
# ...

# %%
# 1) count is 31647 in all columns meaning no null value present
# 2) skewness:- right skewed :- job , marital , education , default , loan , contact ,   
# left skewed :- housing , month , poutcome 
# 3) outliers :- maybe present in default ,loan , month

# %%
df2.skew()
# Out:
# job           0.264817
# marital      -0.100071
# education     0.199441
# default       7.149903
# housing      -0.223918
# loan          1.833474
# contact       0.758602
# month        -0.486498
# poutcome     -1.996421
# subscribed    2.377445
# dtype: float64

# %%
#removing skewness using cuberoot method
df2['default']=np.cbrt(df2['default'])
df2['loan']=np.cbrt(df2['loan'])
df2['contact']=np.cbrt(df2['contact'])
df2['poutcome']=np.cbrt(df2['poutcome'])

# %%
df2.skew()
# Out:
# job           0.264817
# marital      -0.100071
# education     0.199441
# default       7.149903
# housing      -0.223918
# loan          1.833474
# contact       0.611566
# month        -0.486498
# poutcome     -2.386125
# subscribed    2.377445
# dtype: float64

# %%
# skewness is reduced for contact but not so much for other columns

# %% [markdown]
# # CHECKING FOR OUTLIERS

# %%
df3=pd.concat([df1,df2],axis=1,join='inner')
df3
# Out:
#           ID       age    balance  day   duration  campaign     pdays  \
# 0      26110  3.825862  12.456918   19   3.530348  1.259921 -1.000000
# 1      40576  3.141381   1.442250   20   4.497941  1.259921 -1.000000
# 2      15320  3.000000   9.622603   18   6.214465  1.000000 -1.000000
# 3      43962  3.848501  14.868480   22   9.535417  1.000000  4.379519
# 4      29842  3.141381   4.918685    4   7.243156  1.000000 -1.000000
# ...      ...       ...        ...  ...        ...       ...       ...
# 31642  36483  3.072317   0.000000   12   4.876999  1.259921 -1.000000
# 31643  40178  3.756286   7.243156    5   7.594363  1.259921 -1.000000
# 31644  19710  3.174802   6.782423    7   3.332222  1.442250 -1.000000
# 31645  38556  3.848501   6.082202   15   2.802039  1.912931  6.958943
# 31646  14156  3.802952   5.886765   11  12.542257  1.259921 -1.000000
#
#        previous  job  marital  education  default  housing  loan  contact  \
# ...

# %%
#check for outliers using boxplot
# for multiple boxplot visualization
plt.figure(figsize=(20,25))
p=1
for i in df1:
    if p<=18:
        ax=plt.subplot(4,4,p)
        sns.boxplot(df[i])
        plt.xlabel(i)
    p+=1

# %%
# we can claerly see that there are outliers present in columns age, balance , duration , campaign , pdays and previous

# %%
#check for outliers using boxplot
# for multiple boxplot visualization
plt.figure(figsize=(20,25))
p=1
for i in df2:
    if p<=10:
        ax=plt.subplot(4,4,p)
        sns.boxplot(df[i])
        plt.xlabel(i)
    p+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 8
#       6 if p<=10:
#       7     ax=plt.subplot(4,4,p)
# ----> 8     sns.boxplot(df[i])
#       9     plt.xlabel(i)
#      10 p+=1
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
# ...

# %%
#removing outliers
from scipy.stats import zscore
df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
c=df3[['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
       'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
       'pdays', 'previous', 'poutcome', 'subscribed']]
z=np.abs(zscore(c))
z
# Out:
#              ID       age       job   marital  education   default   balance  \
# 0      0.271192  1.383398  1.324317  0.275405   2.369229  0.137234  0.757778
# 1      1.377516  0.961854  2.037729  0.275405   0.300345  0.137234  0.911548
# 2      0.554001  1.446270  0.815167  0.275405   0.300345  0.137234  0.328224
# 3      1.636469  1.460966  0.101755  1.922374   1.034442  0.137234  1.123262
# 4      0.556606  0.961854  1.426448  0.275405   0.300345  0.137234  0.384677
# ...         ...       ...       ...       ...        ...       ...       ...
# 31642  1.064493  1.198489  0.101755  1.371563   1.034442  0.137234  1.130128
# 31643  1.347078  1.145007  0.101755  1.922374   1.034442  0.137234  0.032392
# 31644  0.218265  0.847342  0.101755  1.371563   1.034442  0.137234  0.102219
# 31645  1.223031  1.460966  1.426448  0.275405   0.300345  0.137234  0.208341
# 31646  0.643021  1.304902  0.101755  1.922374   0.300345  0.137234  0.237960
#
# ...

# %%
# above table shows z score of all columns 
# z score less than 3 contains 99.7% data

# %%
#threshold=3
np.where(z>3)
#z score greater than 3 meaning outliers
# these values represent outliers
# Out:
# (array([   10,    21,   109, ..., 31618, 31645, 31646], dtype=int64),
#  array([ 5, 13,  5, ...,  5, 15, 12], dtype=int64))

# %%
# it shows the position of outliers in the dataset
# 1st array is row number and 2nd array is column number

# %%
df4=z[(z<3).all(axis=1)]
df4
# we will select/choose only that data having z score less than 3 thus removing outlier values
# Out:
#              ID       age       job   marital  education   default   balance  \
# 0      0.271192  1.383398  1.324317  0.275405   2.369229  0.137234  0.757778
# 1      1.377516  0.961854  2.037729  0.275405   0.300345  0.137234  0.911548
# 2      0.554001  1.446270  0.815167  0.275405   0.300345  0.137234  0.328224
# 3      1.636469  1.460966  0.101755  1.922374   1.034442  0.137234  1.123262
# 4      0.556606  0.961854  1.426448  0.275405   0.300345  0.137234  0.384677
# ...         ...       ...       ...       ...        ...       ...       ...
# 31640  0.799571  0.278533  0.101755  1.371563   0.300345  0.137234  1.047872
# 31641  1.000936  0.307972  1.426448  1.371563   1.034442  0.137234  0.527739
# 31642  1.064493  1.198489  0.101755  1.371563   1.034442  0.137234  1.130128
# 31643  1.347078  1.145007  0.101755  1.922374   1.034442  0.137234  0.032392
# 31644  0.218265  0.847342  0.101755  1.371563   1.034442  0.137234  0.102219
#
# ...

# %%
df.shape
#old dataset
# Out:
# (31647, 18)

# %%
df4.shape
# new dataset
# Out:
# (29464, 18)

# %%
# 2183 rows are removed to remove outliers

# %%
#this is percentage loss of data. max data that we can afford to lose is 10%
# since our value is 6.89% we lose 6.89% data which is within 10% range
#we cannot lose too much data as some data might be essential for model building
(df.shape[0]-df4.shape[0])/(df.shape[0])*100
# Out:
# 6.897968211836824

# %% [markdown]
# # CHECK FOR CORRELATION AND MULTICOLLINEARITY

# %%
df4.corr()
# Out:
#                   ID       age       job   marital  education  default  \
# ID          1.000000  0.115062  0.049418  0.054415   0.016101      NaN
# age         0.115062  1.000000 -0.088722  0.078916   0.046548      NaN
# job         0.049418 -0.088722  1.000000  0.033008  -0.219974      NaN
# marital     0.054415  0.078916  0.033008  1.000000  -0.061678      NaN
# education   0.016101  0.046548 -0.219974 -0.061678   1.000000      NaN
# default          NaN       NaN       NaN       NaN        NaN      NaN
# balance    -0.034583 -0.003158 -0.026170 -0.020747   0.004200      NaN
# housing    -0.213440  0.169770 -0.087213  0.014928   0.077885      NaN
# loan       -0.069513 -0.017565  0.021756 -0.034806  -0.071123      NaN
# contact     0.460565 -0.024898  0.055261 -0.034912   0.039105      NaN
# day        -0.016381  0.025104  0.020926  0.031162  -0.004889      NaN
# month      -0.132773  0.024791 -0.030817 -0.014960  -0.014652      NaN
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df4.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# heat map for new dataset
# Out:
# <Axes: >

# %%
# we can see the correlation through the heatmap
# we can see from the heatmap that there is multicollinearity present in some columns

# %%
df2.corr()
# Out:
#                  job   marital  education   default   housing      loan  \
# job         1.000000  0.066124   0.170347 -0.005217 -0.125347 -0.039049
# marital     0.066124  1.000000   0.107547 -0.009591 -0.017846 -0.041654
# education   0.170347  0.107547   1.000000 -0.006774 -0.095376 -0.045950
# default    -0.005217 -0.009591  -0.006774  1.000000 -0.011823  0.081567
# housing    -0.125347 -0.017846  -0.095376 -0.011823  1.000000  0.036244
# loan       -0.039049 -0.041654  -0.045950  0.081567  0.036244  1.000000
# contact    -0.074831 -0.042267  -0.116496  0.009821  0.166854 -0.012244
# month      -0.089384 -0.003834  -0.055967  0.004694  0.271442  0.024186
# poutcome    0.009140 -0.014109  -0.013107  0.031525 -0.101403  0.002834
# subscribed  0.038921  0.046043   0.066051 -0.020168 -0.141092 -0.072266
#
#              contact     month  poutcome  subscribed
# job        -0.074831 -0.089384  0.009140    0.038921
# marital    -0.042267 -0.003834 -0.014109    0.046043
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df2.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
# heat map for new dataset
# Out:
# <Axes: >

# %%
# vif factor is checked for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(df4.values,i) for i in range(len(df4.columns))]
vif['features']=df4.columns
vif
# Out:
#     VIF values    features
# 0     1.665311          ID
# 1     1.077558         age
# 2     1.069257         job
# 3     1.021627     marital
# 4     1.068206   education
# 5   144.342074     default
# 6     1.005092     balance
# 7     1.170685     housing
# 8     1.030863        loan
# 9     1.705549     contact
# 10    1.042771         day
# 11    1.165706       month
# 12    1.073617    duration
# 13    1.010297    campaign
# 14    6.417440       pdays
# 15    5.293819    previous
# 16    2.310995    poutcome
# 17    1.258987  subscribed

# %%
# from corr function and vif factor we can see that data is not much correlated with each other so there no need to remove any 
# extra data or column. we can remove default column as it contains high multicollinerarity but it is also important for the
# prediction of labels/target variable

# %%
# vif factor is checked for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif1=pd.DataFrame()
vif1['VIF values']=[variance_inflation_factor(df2.values,i) for i in range(len(df2.columns))]
vif1['features']=df2.columns
vif1
# Out:
#    VIF values    features
# 0    2.702139         job
# 1    4.148147     marital
# 2    3.540629   education
# 3    1.027040     default
# 4    2.370970     housing
# 5    1.198845        loan
# 6    1.938460     contact
# 7    4.612150       month
# 8    5.782249    poutcome
# 9    1.173779  subscribed

# %%
# from corr function and vif factor we can see that data is not much correlated with each other so there no need to remove any 
# extra data or any column

# %%
#checking the value counts of each column
for i in df.columns:
    print(df4[i].value_counts())
# Out:
# ID
# 0.271192    1
# 0.666581    1
# 0.893256    1
# 0.469264    1
# 0.262622    1
#            ..
# 0.338258    1
# 0.268362    1
# 0.475693    1
# 1.682810    1
# 0.218265    1
# Name: count, Length: 29464, dtype: int64
# age
# 0.847342    1370
# 0.735191    1316
# 0.961854    1304
# 0.517510    1223
# 0.625283    1222
#             ...
# 2.259826      23
# 2.914265      22
# 2.582432      21
# 2.976562      14
# 2.745731       8
# Name: count, Length: 62, dtype: int64
# job
# 1.018676    6414
# 0.101755    6146
# 1.426448    4945
# 1.324317    3410
# 0.815167    2738
# 0.203886    1409
# 0.509527    1034
# 0.713036     918
# 1.732089     842
# 0.407395     816
# 1.120808     603
# 2.037729     189
# Name: count, dtype: int64
# marital
# 0.275405    17797
# 1.371563     8325
# 1.922374     3342
# Name: count, dtype: int64
# education
# 0.300345    15161
# 1.034442     8622
# 1.635132     4465
# 2.369229     1216
# Name: count, dtype: int64
# default
# 0.137234    29464
# ...

# %%
# splitting data in x(features/attributes) and y(label/target value)
# x1=original df data attributes
# x3= labelencoding of x1 object datatype data only
# x4=original data attributes int64 datatype only
# x5 = x4 + x3
# x2 =labelencoding of object datatype + int64 datatype attributes

# %%
x1=df.iloc[:,:-1]
x1
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x3=pd.DataFrame()
for i in x1.columns:
    if x1[i].dtypes=='object':
        x3[i]=le.fit_transform(x1[i].values.reshape(-1,1))
x3
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        0        1          3        0        0     0        1      9
# 1       11        1          1        0        0     0        0      5
# 2        7        1          1        0        1     0        0      5
# 3        4        0          2        0        0     0        0      6
# 4        9        1          1        0        1     0        0      3
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 31642    4        2          2        0        1     0        0      8
# 31643    4        0          2        0        0     1        0      6
# 31644    4        2          2        0        0     0        0      1
# 31645    9        1          1        0        1     0        1      8
# 31646    4        0          1        0        1     0        0      5
#
#        poutcome
# 0             3
# 1             3
# 2             3
# 3             2
# 4             3
# ...

# %%
x4=pd.DataFrame()
for i in x1.columns:
    if x1[i].dtypes=='int64':
        x4[i]=x1[i].values
    if x1[i].dtypes=='float64':
        x4[i]=x1[i].values
x4
# Out:
#           ID  age  balance  day  duration  campaign  pdays  previous
# 0      26110   56     1933   19        44         2     -1         0
# 1      40576   31        3   20        91         2     -1         0
# 2      15320   27      891   18       240         1     -1         0
# 3      43962   57     3287   22       867         1     84         3
# 4      29842   31      119    4       380         1     -1         0
# ...      ...  ...      ...  ...       ...       ...    ...       ...
# 31642  36483   29        0   12       116         2     -1         0
# 31643  40178   53      380    5       438         2     -1         0
# 31644  19710   32      312    7        37         3     -1         0
# 31645  38556   57      225   15        22         7    337        12
# 31646  14156   55      204   11      1973         2     -1         0
#
# [31647 rows x 8 columns]

# %%
x5=pd.concat([x3,x4],axis=1,join='inner')
x5
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        0        1          3        0        0     0        1      9
# 1       11        1          1        0        0     0        0      5
# 2        7        1          1        0        1     0        0      5
# 3        4        0          2        0        0     0        0      6
# 4        9        1          1        0        1     0        0      3
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 31642    4        2          2        0        1     0        0      8
# 31643    4        0          2        0        0     1        0      6
# 31644    4        2          2        0        0     0        0      1
# 31645    9        1          1        0        1     0        1      8
# 31646    4        0          1        0        1     0        0      5
#
#        poutcome     ID  age  balance  day  duration  campaign  pdays  previous
# ...

# %%
y1=df.iloc[:,-1]
y1
# Out:
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no
#         ...
# 31642     no
# 31643    yes
# 31644     no
# 31645     no
# 31646    yes
# Name: subscribed, Length: 31647, dtype: object

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
x2,y2=sm.fit_resample(x5,y1)

# %%
y2.value_counts()
# Out:
# subscribed
# no     27932
# yes    27932
# Name: count, dtype: int64

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# standard scaler is done so as to make all values from whole data on the same level/range.
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x5=pd.DataFrame(s.fit_transform(x5),columns=x5.columns)
x5
# Out:
#             job   marital  education   default   housing      loan   contact  \
# 0     -1.324317 -0.275405   2.369229 -0.137234 -1.118201 -0.439893  0.395076
# 1      2.037729 -0.275405  -0.300345 -0.137234 -1.118201 -0.439893 -0.716695
# 2      0.815167 -0.275405  -0.300345 -0.137234  0.894294 -0.439893 -0.716695
# 3     -0.101755 -1.922374   1.034442 -0.137234 -1.118201 -0.439893 -0.716695
# 4      1.426448 -0.275405  -0.300345 -0.137234  0.894294 -0.439893 -0.716695
# ...         ...       ...        ...       ...       ...       ...       ...
# 31642 -0.101755  1.371563   1.034442 -0.137234  0.894294 -0.439893 -0.716695
# 31643 -0.101755 -1.922374   1.034442 -0.137234 -1.118201  2.273280 -0.716695
# 31644 -0.101755  1.371563   1.034442 -0.137234 -1.118201 -0.439893 -0.716695
# 31645  1.426448 -0.275405  -0.300345 -0.137234  0.894294 -0.439893  0.395076
# 31646 -0.101755 -1.922374  -0.300345 -0.137234  0.894294 -0.439893 -0.716695
#
# ...

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x5,y1,test_size=0.30,random_state=i)
    rfr= RandomForestClassifier()
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('best accuracy is',maxaccu,'at random state',maxrs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 6
#       4 x_train,x_test,y_train,y_test=train_test_split(x5,y1,test_size=0.30,random_state=i)
#       5 rfr= RandomForestClassifier()
# ----> 6 rfr.fit(x_train,y_train)
#       7 pred=rfr.predict(x_test)
#       8 acc=accuracy_score(y_test,pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dfa=pd.DataFrame()
for i in df.columns:
    dfa[i]=le.fit_transform(df[i].values.reshape(-1,1))
dfa
# Out:
#           ID  age  job  marital  education  default  balance  housing  loan  \
# 0      18299   38    0        1          3        0     2719        0     0
# 1      28379   13   11        1          1        0      822        0     0
# 2      10766    9    7        1          1        0     1709        1     0
# 3      30772   39    4        0          2        0     3815        0     0
# 4      20922   13    9        1          1        0      938        1     0
# ...      ...  ...  ...      ...        ...      ...      ...      ...   ...
# 31642  25522   11    4        2          2        0      819        1     0
# 31643  28103   35    4        0          2        0     1199        0     1
# 31644  13887   14    4        2          2        0     1131        0     0
# 31645  26950   39    9        1          1        0     1044        1     0
# 31646   9956   37    4        0          1        0     1023        1     0
#
# ...

# %%
x=dfa.iloc[:,:-1]
x
# Out:
#           ID  age  job  marital  education  default  balance  housing  loan  \
# 0      18299   38    0        1          3        0     2719        0     0
# 1      28379   13   11        1          1        0      822        0     0
# 2      10766    9    7        1          1        0     1709        1     0
# 3      30772   39    4        0          2        0     3815        0     0
# 4      20922   13    9        1          1        0      938        1     0
# ...      ...  ...  ...      ...        ...      ...      ...      ...   ...
# 31642  25522   11    4        2          2        0      819        1     0
# 31643  28103   35    4        0          2        0     1199        0     1
# 31644  13887   14    4        2          2        0     1131        0     0
# 31645  26950   39    9        1          1        0     1044        1     0
# 31646   9956   37    4        0          1        0     1023        1     0
#
# ...

# %%
y=dfa.iloc[:,-1]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31642    0
# 31643    1
# 31644    0
# 31645    0
# 31646    1
# Name: subscribed, Length: 31647, dtype: int32

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    rfr= RandomForestClassifier()
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('best accuracy is',maxaccu,'at random state',maxrs)
# Out:
# best accuracy is 0.9180621379673513 at random state 154

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#random forest classifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=154)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
predrfc=rfc.predict(x_test)
print('accuracy score',accuracy_score(y_test,predrfc))
print('confusion matrix',confusion_matrix(y_test,predrfc))
print('classification',classification_report(y_test,predrfc))
# Out:
# accuracy score 0.9179568193786203
# confusion matrix [[8165  272]
#  [ 507  551]]
# classification               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      8437
#            1       0.67      0.52      0.59      1058
#
#     accuracy                           0.92      9495
#    macro avg       0.81      0.74      0.77      9495
# weighted avg       0.91      0.92      0.91      9495

# %%
lr= LogisticRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.8876250658241179
# [[8183  254]
#  [ 813  245]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      8437
#            1       0.49      0.23      0.31      1058
#
#     accuracy                           0.89      9495
#    macro avg       0.70      0.60      0.63      9495
# weighted avg       0.86      0.89      0.87      9495

# %%
svc= SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8884676145339653
# [[8436    1]
#  [1058    0]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      8437
#            1       0.00      0.00      0.00      1058
#
#     accuracy                           0.89      9495
#    macro avg       0.44      0.50      0.47      9495
# weighted avg       0.79      0.89      0.84      9495

# %%
gbc= GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predgbc=gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.9170089520800421
# [[8143  294]
#  [ 494  564]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      8437
#            1       0.66      0.53      0.59      1058
#
#     accuracy                           0.92      9495
#    macro avg       0.80      0.75      0.77      9495
# weighted avg       0.91      0.92      0.91      9495

# %%
abc= AdaBoostClassifier()
abc.fit(x_train,y_train)
predabc=abc.predict(x_test)
print(accuracy_score(y_test,predabc))
print(confusion_matrix(y_test,predabc))
print(classification_report(y_test,predabc))
# Out:
# 0.9074249605055292
# [[8207  230]
#  [ 649  409]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      8437
#            1       0.64      0.39      0.48      1058
#
#     accuracy                           0.91      9495
#    macro avg       0.78      0.68      0.72      9495
# weighted avg       0.89      0.91      0.90      9495

# %%
bc= BaggingClassifier()
bc.fit(x_train,y_train)
predbc=bc.predict(x_test)
print(accuracy_score(y_test,predbc))
print(confusion_matrix(y_test,predbc))
print(classification_report(y_test,predbc))
# Out:
# 0.9142706687730384
# [[8159  278]
#  [ 536  522]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      8437
#            1       0.65      0.49      0.56      1058
#
#     accuracy                           0.91      9495
#    macro avg       0.80      0.73      0.76      9495
# weighted avg       0.91      0.91      0.91      9495

# %%
etc= ExtraTreesClassifier()
etc.fit(x_train,y_train)
predetc=etc.predict(x_test)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.9134281200631912
# [[8209  228]
#  [ 594  464]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      8437
#            1       0.67      0.44      0.53      1058
#
#     accuracy                           0.91      9495
#    macro avg       0.80      0.71      0.74      9495
# weighted avg       0.90      0.91      0.91      9495

# %%
# accuracy score of rfc= 91.79% ,lr=88.76% ,svc=88.84% ,gbc=91.70% ,abc=90.74% ,bc=91.42% ,etc=91.34%
#as we can see that rfc has highest accuracy score of 91.79%
#we can also look for other values in confusion matrix and classification report like precision, recall, f1 score etc.

# %%
from sklearn.model_selection import cross_val_score
cvs= cross_val_score
rfcscore=cvs(rfc,x,y)
print(rfcscore)
print(rfcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predrfc)-rfcscore.mean())
# Out:
# [0.91484992 0.91153239 0.90930637 0.91151841 0.91041239]
# 0.9115238937492027
# differnce b/w accuracy score and cross val score 0.006432925629417552

# %%
lrscore=cvs(lr,x,y)
print(lrscore)
print(lrscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predlr)-lrscore.mean())
# Out:
# [0.8864139  0.88135861 0.88039185 0.88702797 0.87960183]
# 0.8829588316475953
# differnce b/w accuracy score and cross val score 0.004666234176522677

# %%
svcscore=cvs(svc,x,y)
print(svcscore)
print(svcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predsvc)-svcscore.mean())
# Out:
# [0.88262243 0.88262243 0.88276189 0.88260389 0.88260389]
# 0.8826429058345482
# differnce b/w accuracy score and cross val score 0.005824708699417092

# %%
gbcscore=cvs(gbc,x,y)
print(gbcscore)
print(gbcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predgbc)-gbcscore.mean())
# Out:
# [0.91406003 0.9107425  0.90820035 0.91294043 0.91072839]
# 0.911334340258251
# differnce b/w accuracy score and cross val score 0.005674611821791076

# %%
abcscore=cvs(abc,x,y)
print(abcscore)
print(abcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predabc)-abcscore.mean())
# Out:
# [0.90394945 0.90473934 0.89872018 0.90646232 0.90314426]
# 0.9034031066903596
# differnce b/w accuracy score and cross val score 0.004021853815169618

# %%
bcscore=cvs(bc,x,y)
print(bcscore)
print(bcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predbc)-bcscore.mean())
# Out:
# [0.90331754 0.90157978 0.90172223 0.90693632 0.90393427]
# 0.9034980282093734
# differnce b/w accuracy score and cross val score 0.010772640563665004

# %%
etcscore=cvs(etc,x,y)
print(etcscore)
print(etcscore.mean())
print('differnce b/w accuracy score and cross val score',accuracy_score(y_test,predetc)-etcscore.mean())
# Out:
# [0.91026856 0.9093207  0.90978038 0.90851635 0.90393427]
# 0.9083640515323903
# differnce b/w accuracy score and cross val score 0.00506406853080088

# %%
#difference b/w accuracy score and cross val score of rfc=0.006 , lr=0.004 ,svc=0.005 , gbc=0.005 ,abc=0.004 ,bc=0.0107 ,etc=0.005
# accuracy score of rfc= 91.79% ,lr=88.76% ,svc=88.84% ,gbc=91.70% ,abc=90.74% ,bc=91.42% ,etc=91.34%
# cross val score of rfc=91.15% ,lr=88.29% ,svc=88.26% ,gbc=91.13% ,abc=90.34% ,bc=90.34% ,etc=90.83%
# % difference in as and cvs of rfc=0.6% ,lr=0.4% ,svc=0.5% ,gbc=0.5% ,abc=0.4% ,bc=1.07% ,0.5%
# considering both (difference in cvs and ac) and accuracy score best model should be random forest classifer as accuracy 
# is 91.15%
# and difference is less (0.6%) other models which are good are gbc,etc and abc

# %% [markdown]
# # SAVING THE MODEL AND LOADING THE MODEL AND PREDICTING BASED ON THE MODEL

# %%
import joblib
joblib.dump(rfc,'BANK MARKETING project')
# Out:
# ['BANK MARKETING project']

# %%
p=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_test.csv')
p
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
p1=pd.DataFrame()
for i in p.columns:
    p1[i]=le.fit_transform(p[i].values.reshape(-1,1))
p1
# Out:
#           ID  age  job  marital  education  default  balance  housing  loan  \
# 0      11570   14    7        1          1        0      682        1     0
# 1      12143   60    5        0          0        0     2809        0     0
# 2       1104   13    6        2          2        0      708        1     0
# 3      11242   39    7        2          0        0     3226        1     0
# 4       3686   27    1        0          1        0       94        0     1
# ...      ...  ...  ...      ...        ...      ...      ...      ...   ...
# 13559   6989   21    4        1          2        0      609        0     0
# 13560   3456   36    1        1          0        0     2535        1     0
# 13561   8450   17    5        1          0        0      849        1     0
# 13562  13551   11    0        2          1        0     1028        0     0
# 13563  10431   11    0        1          1        0      566        1     0
#
# ...

# %%
model=joblib.load('BANK MARKETING project')
prediction=model.predict(p1)
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# 0 means not subscribed
# 1 means subscribed
